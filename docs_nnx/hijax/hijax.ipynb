# %% [markdown]
# # Hijax

# %%
from flax import nnx
import jax
import jax.numpy as jnp
import optax

current_mode = nnx.using_hijax() # ignore: only needed for testing

# %%
nnx.use_hijax(True)

rngs = nnx.Rngs(0)
model = nnx.Linear(2, 3, rngs=rngs)
optimizer = nnx.Optimizer(model, optax.adamw(1e-2), wrt=nnx.Param)

@jax.jit
def train_step(x, y):
  loss_fn = lambda m: jnp.mean((m(x) - y) ** 2)
  loss, grads = jax.value_and_grad(loss_fn)(model)  # tmp fix for jax.grad
  optimizer.update(model, grads)
  return loss

x, y = rngs.uniform((4, 2)), rngs.uniform((4, 3))
for _ in range(3):
  print(train_step(x, y))
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:149, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     148 else:
# --> 149   out_flat = jit_p.bind(*args_flat, **p.params)
#     150   compiled = None
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     631 args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632 return self._true_bind(*args, **params)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:659, in Primitive.bind_with_trace(self, trace, args, params)
#     658   with set_current_trace(trace):
# --> 659     return self.to_lojax(*args, **params)  # type: ignore
#     660 return trace.process_primitive(self, args, params)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1346, in _to_lojax(jaxpr, *hi_args, **params)
#    1345 lo_jaxpr = pe.lower_jaxpr(jaxpr)
# -> 1346 all_outs = jit_p.bind(*lo_args, jaxpr=lo_jaxpr, **params)
#    1347 out_mut, lo_outs = split_list(all_outs, [lo_muts_out])
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     631 args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632 return self._true_bind(*args, **params)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:660, in Primitive.bind_with_trace(self, trace, args, params)
#     659       return self.to_lojax(*args, **params)  # type: ignore
# --> 660   return trace.process_primitive(self, args, params)
#     661 trace.process_primitive(self, args, params)  # may raise lojax error
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1188 # check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1691, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1684 cache_key = pxla.JitGlobalCppCacheKeys(
#    1685     donate_argnums=donated_argnums, donate_argnames=None,
#    1686     device=None, backend=None,
#    (...)   1689     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1690     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1691 return xc._xla.pjit(
#    1692     name, f, call_impl_cache_miss, [], [], cache_key,
#    1693     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1694     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1667, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1663 def call_impl_cache_miss(*args_, **kwargs_):
#    1664   # args_ do not include the const args
#    1665   # See https://docs.jax.dev/en/latest/internals/constants.html.
#    1666   # TODO(necula): remove num_const_args when fixing the C++ path
# -> 1667   out_flat, compiled, pgle_profiler, const_args = _pjit_call_impl_python(
#    1668       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1669       out_shardings=out_shardings, in_layouts=in_layouts,
#    1670       out_layouts=out_layouts, donated_invars=donated_invars,
#    1671       ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1672       inline=inline, compiler_options_kvs=compiler_options_kvs)
#    1673   fastpath_data = _get_fastpath_data(
#    1674       compiled, tree_structure(out_flat), args, out_flat,
#    1675       jaxpr.effects, jaxpr.consts, None, pgle_profiler,
#    1676       const_args)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1642, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1635   distributed_debug_log(("Running pjit'd function", name),
#    1636                         ("in_shardings", in_shardings),
#    1637                         ("out_shardings", out_shardings),
#    (...)   1640                         ("abstract args", map(core.abstractify, args)),
#    1641                         ("fingerprint", fingerprint))
# -> 1642 return (compiled.unsafe_call(*computation.const_args, *args),
#    1643         compiled, pgle_profiler, computation.const_args)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/profiler.py:359, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     358 with TraceAnnotation(name, **decorator_kwargs):
# --> 359   return func(*args, **kwargs)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1366, in ExecuteReplicated.__call__(self, *args)
#    1365   args = [*args, *self.mut.in_mut]
# -> 1366 input_bufs = self.in_handler(args)
#    1367 with profiler.PGLEProfiler.trace(self.pgle_profiler):
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1249, in InputsHandler.__call__(self, input_buffers)
#    1248 def __call__(self, input_buffers):
# -> 1249   return self.handler(input_buffers)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/profiler.py:359, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     358 with TraceAnnotation(name, **decorator_kwargs):
# --> 359   return func(*args, **kwargs)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:134, in shard_args(shardings, layouts, copy_semantics, args, canonicalize)
#     133 if canonicalize:
# --> 134   arg = dtypes.canonicalize_value(arg)
#     135 batch = batches[type(arg)]
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/dtypes.py:388, in canonicalize_value(x)
#     383   raise ValueError(
#     384       'Triggering __jax_array__() during abstractification is no longer'
#     385       ' supported. To avoid this error, either explicitly convert your object'
#     386       ' using jax.numpy.array(), or register your object as a pytree.'
#     387   )
# --> 388 raise InvalidInputException(
#     389     f"Argument '{x}' of type {type(x)} is not a valid JAX type."
#     390 )
#
# InvalidInputException: Argument 'JitTracer<float32[3]>' of type <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'> is not a valid JAX type.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 16
#      14 x, y = rngs.uniform((4, 2)), rngs.uniform((4, 3))
#      15 for _ in range(3):
# ---> 16   print(train_step(x, y))
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:264, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     259 if config.no_tracing.value:
#     260   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     261                      "`jit`, but 'no_tracing' is set")
#     263 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 264  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     265      fun, jit_info, *args, **kwargs)
#     267 maybe_fastpath_data = _get_fastpath_data(
#     268     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     269     jit_info.abstracted_axes, pgle_profiler,
#     270     const_args)
#     272 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/repos/flax/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:166, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     164   raise TypeError(e.args[0]) from e
#     165 else:
# --> 166   for arg, name, aval in zip(args_flat, arg_names, p.in_avals):
#     167     try:
#     168       dtypes.canonicalize_value(arg)
#
# ValueError: safe_zip() argument 2 is shorter than argument 1

# %% [markdown]
# ## Hijax Variable

# %% [markdown]
# State propagation:

# %%
v = nnx.Variable(jnp.array(0), is_hijax=True)

@jax.jit
def inc(v):
  v[...] += 1

print(v[...]); inc(v); print(v[...])
# Out:
# 0
# 1

# %%
v = nnx.Variable(jnp.array(0), is_hijax=True)
print(jax.make_jaxpr(inc)(v))
# Out:
# { lambda ; a:Variable(). let
#     jit[
#       name=inc
#       jaxpr={ lambda ; a:Variable(). let
#           b:i32[] = get_variable[avals=(ShapedArray(int32[], weak_type=True),)] a
#           c:i32[] = add b 1:i32[]
#           _:i32[] = get_variable[avals=(ShapedArray(int32[], weak_type=True),)] a
#           set_variable[
#             treedef=PyTreeDef(CustomNode(Variable[(('has_ref', False), ('is_hijax', True), ('is_mutable', True))], [*]))
#             var_type=<class 'flax.nnx.variablelib.Variable'>
#           ] a c
#         in () }
#     ] a
#   in () }

# %% [markdown]
# Pytree values:

# %%
v = nnx.Variable({'a': jnp.array(0), 'b': jnp.array(2)}, is_hijax=True)

@jax.jit
def inc_and_double(v):
  v['a'] += 1
  v['b'] *= 2

print(v); inc_and_double(v); print(v)
# Out:
# Variable( # 2 (8 B)
#   value={'a': Array(0, dtype=int32, weak_type=True), 'b': Array(2, dtype=int32, weak_type=True)},
#   is_hijax=True
# )
# Variable( # 2 (8 B)
#   value={'a': Array(1, dtype=int32, weak_type=True), 'b': Array(4, dtype=int32, weak_type=True)},
#   is_hijax=True
# )

# %% [markdown]
# Dynamic state structure:

# %%
rngs = nnx.Rngs(0)
x = rngs.uniform((4, 5))
w = rngs.normal((5, 3))
metrics = nnx.Variable({}, is_hijax=True)

@jax.jit
def linear(x, w, metrics: nnx.Variable):
  y = x @ w
  metrics['y_mean'] = jnp.mean(y)
  return y

print("Before:", metrics)
y = linear(x, w, metrics)
print("After:", metrics)
# Out:
# Before: Variable(
#   value={},
#   is_hijax=True
# )
# After: Variable( # 1 (4 B)
#   value={'y_mean': Array(-1.1782329, dtype=float32)},
#   is_hijax=True
# )

# %%
# set default Variable mode for the rest of the guide
nnx.use_hijax(True)

variable = nnx.Variable(jnp.array([1, 2, 3]))

print(variable)
# Out:
# Variable( # 3 (12 B)
#   value=Array([1, 2, 3], dtype=int32),
#   is_hijax=True
# )

# %% [markdown]
# ### Mutability

# %%
class Linear(nnx.Module):
  def __init__(self, in_features, out_features, rngs: nnx.Rngs):
    self.kernel = nnx.Param(rngs.normal((in_features, out_features)))

  def __call__(self, x):
    return x @ self.kernel

model = Linear(1, 3, rngs=nnx.Rngs(0))

print(f"{nnx.as_immutable_vars(model) = !s}")
print(f"{nnx.as_mutable_vars(model) = !s}")
# Out:
# nnx.as_immutable_vars(model) = Linear( # Param: 3 (12 B)
#   kernel=Param(
#     value=Array(shape=(1, 3), dtype=dtype('float32')),
#     is_mutable=False,
#     was_hijax=True
#   )
# )
# nnx.as_mutable_vars(model) = Linear( # Param: 3 (12 B)
#   kernel=Param(
#     value=Array(shape=(1, 3), dtype=dtype('float32')),
#     is_hijax=True
#   )
# )

# %%
v = nnx.Variable(jnp.array(0))
v_immut = nnx.as_immutable_vars(v)
assert not v_immut.is_mutable

try:
  v_immut[...] += 1  # raises an error
except Exception as e:
  print(f"{type(e).__name__}: {e}")
# Out:
# ImmutableVariableError: Cannot mutate Variable as it is marked as immutable. (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.ImmutableVariableError)

# %% [markdown]
# ### Ref support

# %%
v = nnx.Variable(jnp.array(0))
v_ref = nnx.as_ref_vars(v)
assert v_ref.has_ref
print(v_ref)
print(v_ref.get_raw_value())
# Out:
# Variable( # 1 (4 B)
#   value=Array(0, dtype=int32, weak_type=True),
#   has_ref=True
# )
# Ref(0, dtype=int32, weak_type=True)

# %%
v_immut = nnx.as_immutable_vars(v_ref)
assert not v_immut.has_ref
print("immutable =", v_immut)

v_ref = nnx.as_mutable_vars(v_immut)
assert v_ref.has_ref
print("mutable =", v_ref)
# Out:
# immutable = Variable( # 1 (4 B)
#   value=Array(0, dtype=int32, weak_type=True),
#   is_mutable=False,
#   had_ref=True
# )
# mutable = Variable( # 1 (4 B)
#   value=Array(0, dtype=int32, weak_type=True),
#   has_ref=True
# )

# %% [markdown]
# ### Examples

# %%
class Block(nnx.Module):
  def __init__(self, din, dmid, dout, rngs: nnx.Rngs):
    self.linear = Linear(din, dmid, rngs=rngs)
    self.bn = nnx.BatchNorm(dmid, rngs=rngs)
    self.dropout = nnx.Dropout(0.1, rngs=rngs)
    self.linear_out = Linear(dmid, dout, rngs=rngs)

  def __call__(self, x):
    x = nnx.gelu(self.dropout(self.bn(self.linear(x))))
    return self.linear_out(x)

# %% [markdown]
# #### Training Loop

# %%
# hijax Variables by default
model = Block(2, 64, 3, rngs=nnx.Rngs(0))
optimizer = nnx.Optimizer(model, optax.adam(1e-3), wrt=nnx.Param)

@jax.jit
def train_step(model, optimizer, x, y):
  graphdef, params, nondiff = nnx.split(model, nnx.Param, ...)
  def loss_fn(params):
    model =  nnx.merge(graphdef, params, nondiff)
    return ((model(x) - y) ** 2).mean()

  loss, grads = jax.value_and_grad(loss_fn)(nnx.as_immutable_vars(params))  # lojax Variables for jax.grad
  optimizer.update(model, grads)

  return loss

for _ in range(3):
  loss = train_step(model, optimizer, x=jnp.ones((10, 2)), y=jnp.ones((10, 3)))
  print(f"{loss = !s}")
# Out:
# loss = 1.000178
# loss = 0.9700456
# loss = 0.93967044

# %% [markdown]
# #### Scan Over Layers

# %%
# TODO: does not work with hijax yet
# @jax.vmap
# def create_stack(rngs):
#   return nnx.as_immutable_vars(Block(2, 64, 2, rngs=rngs))

# block_stack = nnx.as_mutable_vars(create_stack(nnx.Rngs(0).fork(split=8)))

# def scan_fn(x, block):
#   x = block(x)
#   return x, None

# x = jax.random.uniform(jax.random.key(0), (3, 2))
# y, _ = jax.lax.scan(scan_fn, x, block_stack)

# print("y = ", y)

# %% [markdown]
# ### Limitations

# %% [markdown]
# #### Mutable Outputs

# %%
@jax.jit
def create_model(rngs):
  return Block(2, 64, 3, rngs=rngs)

try:
  model = create_model(nnx.Rngs(0))
except Exception as e:
  print(f"Error:", e)
# Out:
# Error: mutable hitypes should use lo_ty_qdd instead

# %%
@jax.jit
def create_model(rngs):
  return nnx.as_immutable_vars(Block(2, 64, 3, rngs=rngs))

model = nnx.as_mutable_vars(create_model(nnx.Rngs(0)))

print("model.linear =", model.linear)
# Out:
# model.linear = Linear( # Param: 128 (512 B)
#   kernel=Param(
#     value=Array(shape=(2, 64), dtype=dtype('float32')),
#     is_hijax=True
#   )
# )

# %% [markdown]
# #### Reference Sharing (aliasing)

# %%
# NOTE: doesn't currently fail on the jax side
def get_error(f, *args):
  try:
    return f(*args)
  except Exception as e:
    return f"{type(e).__name__}: {e}"

x = nnx.Variable(jnp.array(0))

@jax.jit
def f(a, b):
  ...

print(get_error(f, x, x))
# Out:
# None

# %%
# NOTE: doesn't currently fail on the jax side
class Shared(nnx.Pytree):
  def __init__(self):
    self.a = nnx.Variable(jnp.array(0))
    self.b = self.a
    self.c = Linear(1, 1, rngs=nnx.Rngs(0))
    self.d = self.c

@jax.jit
def g(pytree):
  ...

shared = Shared()

print(get_error(g, shared))
# Out:
# None

# %%
print("Duplicates found:")
if (all_duplicates := nnx.find_duplicates(shared)):
  for duplicates in all_duplicates:
    print("-", duplicates)
# Out:
# Duplicates found:
# - [('a',), ('b',)]
# - [('c',), ('d',)]

# %%
@jax.jit
def h(graphdef, state):
  obj = nnx.merge(graphdef, state)
  obj.a[...] += 10

graphdef, state = nnx.split(shared)
print("before:", state.a) # split deduplicates the state

h(graphdef, state)

print("after:", shared.a)
# Out:
# before: Variable( # 1 (4 B)
#   value=Array(0, dtype=int32, weak_type=True),
#   is_hijax=True
# )
# after: Variable( # 1 (4 B)
#   value=Array(10, dtype=int32, weak_type=True),
#   is_hijax=True
# )

# %%
# clean up for CI tests
_ = nnx.use_hijax(current_mode)
